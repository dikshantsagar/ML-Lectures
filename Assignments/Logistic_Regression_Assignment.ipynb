# %%
import numpy as np
from numpy import log, dot, e, shape
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")
from sklearn.datasets import load_breast_cancer
# Out:
# <ipython-input-1-3b79e65d9e10>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
x, y = None

# %%
pd.DataFrame(np.concatenate([x,y.reshape(-1,1)], axis=1), columns=["Feature"]*30+[ "Labels"])
# Out:
#      Feature  Feature  Feature  Feature  Feature  Feature  Feature  Feature  \
# 0      17.99    10.38   122.80   1001.0  0.11840  0.27760  0.30010  0.14710
# 1      20.57    17.77   132.90   1326.0  0.08474  0.07864  0.08690  0.07017
# 2      19.69    21.25   130.00   1203.0  0.10960  0.15990  0.19740  0.12790
# 3      11.42    20.38    77.58    386.1  0.14250  0.28390  0.24140  0.10520
# 4      20.29    14.34   135.10   1297.0  0.10030  0.13280  0.19800  0.10430
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 564    21.56    22.39   142.00   1479.0  0.11100  0.11590  0.24390  0.13890
# 565    20.13    28.25   131.20   1261.0  0.09780  0.10340  0.14400  0.09791
# 566    16.60    28.08   108.30    858.1  0.08455  0.10230  0.09251  0.05302
# 567    20.60    29.33   140.10   1265.0  0.11780  0.27700  0.35140  0.15200
# 568     7.76    24.54    47.92    181.0  0.05263  0.04362  0.00000  0.00000
#
# ...

# %%
for g in [0,1]:
  i = np.where(y==g)
  plt.scatter(x[i,0],x[i,1], label=g)
plt.legend(frameon=True)
plt.show()

# %%
def sigmoid(z):
  return None

# %%
def loss(y, y_hat):
  loss = None
  return loss

# %%
def gradients(x, y, y_hat):

  m = x.shape[0]

  dw = (1/m)*np.dot(x.T, (y_hat - y))

  db = (1/m)*np.sum((y_hat - y))

  return dw, db

# %%
def train(x, y, bs, epochs, lr):


  m, n = x.shape

  w = np.zeros((n,1))
  b = 0.

  y = y.reshape(m, 1)

  losses = []


  for epoch in range(None):
    for i in range((m-1)//bs + 1):

      start_i = i*bs
      end_i = start_i + bs
      xb = x[start_i:end_i]
      yb = y[start_i:end_i]

      y_hat = None

      dw, db = gradients(xb, yb, y_hat)

      w -= lr * None
      b -= lr * None


    l = loss(y, None)

    losses.append(l)


  return w, b, losses

# %%
w, b, l = train(x, y, bs = None, epochs = None, lr = None)

# %%
plt.plot(l)
plt.show()

# %%
def predict(X):


    preds = None


    pred_class = []
    # if y_hat >= 0.5 --> round up to 1
    # if y_hat < 0.5 --> round up to 0
    pred_class = [1 if i > None else 0 for i in preds]

    return np.array(pred_class)

# %%
def accuracy(y, y_hat):

  print("Accuracy:", None, "%")

# %%
accuracy(y, predict(x))
# Out:
# Accuracy: 92.44288224956063 %
